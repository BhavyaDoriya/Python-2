# %%
import requests,json

# %%
api_key="api_key"
city_name='surat'
url=f"http://api.openweathermap.org/geo/1.0/direct?q={city_name}&appid={api_key}"
res=requests.get(url)
res.status_code
# Out:
# 401

# %%
result=res.json()
result
# Out:
# [{'name': 'Surat',
#   'local_names': {'oc': 'Surat', 'uk': 'Сюра', 'fr': 'Surat'},
#   'lat': 45.9383,
#   'lon': 3.2553,
#   'country': 'FR',
#   'state': 'Auvergne-Rhône-Alpes'}]

# %%
# import os
# import sys
# import django

# # 1. Add your Django project root to the Python path.
# # Assuming 'p2' is the folder containing manage.py
# project_root = r'C:\Notes\Python\Python2\T3\Project2\p2'
# if project_root not in sys.path:
#     sys.path.append(project_root)

# # 2. Set the settings module. 
# # Replace 'p2.settings' with your actual settings folder name if it's different.
# os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'p2.settings')

# # 3. Allow synchronous ORM calls inside Jupyter's async event loop.
# os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# # 4. Initialize Django
# django.setup()

# print("Django configured successfully!")

# %%
latitude=result[0].get("lat")
longitude=result[0].get("lon")
print(latitude,longitude)
# Out:
# 45.9383 3.2553

# %%
url=f"https://api.openweathermap.org/data/2.5/weather?lat={latitude}&lon={longitude}&appid={api_key}"
res=requests.get(url)
result=res.json()
print(json.dumps(result,indent=5))
# Out:
# {
#      "coord": {
#           "lon": 3.2553,
#           "lat": 45.9383
#      },
#      "weather": [
#           {
#                "id": 803,
#                "main": "Clouds",
#                "description": "broken clouds",
#                "icon": "04d"
#           }
#      ],
#      "base": "stations",
#      "main": {
#           "temp": 290.23,
#           "feels_like": 290,
#           "temp_min": 290.23,
#           "temp_max": 290.23,
#           "pressure": 1012,
#           "humidity": 77,
#           "sea_level": 1012,
#           "grnd_level": 970
#      },
#      "visibility": 10000,
#      "wind": {
#           "speed": 1.03,
#           "deg": 80
#      },
#      "clouds": {
#           "all": 75
#      },
#      "dt": 1780373562,
#      "sys": {
#           "type": 1,
#           "id": 6496,
#           "country": "FR",
#           "sunrise": 1780372785,
#           "sunset": 1780428628
#      },
#      "timezone": 7200,
#      "id": 2979447,
# ...

# %%
result["weather"]
# Out:
# [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]

# %%
url=f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={api_key}"
res=requests.get(url)
result=res.json()
print(json.dumps(result,indent=5))
# Out:
# {
#      "cod": "200",
#      "message": 0,
#      "cnt": 40,
#      "list": [
#           {
#                "dt": 1780380000,
#                "main": {
#                     "temp": 290.23,
#                     "feels_like": 290,
#                     "temp_min": 289.59,
#                     "temp_max": 290.23,
#                     "pressure": 1012,
#                     "sea_level": 1012,
#                     "grnd_level": 970,
#                     "humidity": 77,
#                     "temp_kf": 0.64
#                },
#                "weather": [
#                     {
#                          "id": 803,
#                          "main": "Clouds",
#                          "description": "broken clouds",
#                          "icon": "04d"
#                     }
#                ],
#                "clouds": {
#                     "all": 75
#                },
#                "wind": {
#                     "speed": 1.98,
#                     "deg": 177,
# ...

# %%
result["list"][0]["main"]
# Out:
# {'temp': 290.23,
#  'feels_like': 290,
#  'temp_min': 289.59,
#  'temp_max': 290.23,
#  'pressure': 1012,
#  'sea_level': 1012,
#  'grnd_level': 970,
#  'humidity': 77,
#  'temp_kf': 0.64}

# %%
import pandas as pd
df=pd.DataFrame(result["list"])
df
# Out:
#             dt                                               main  \
# 0   1780380000  {'temp': 290.23, 'feels_like': 290, 'temp_min'...
# 1   1780390800  {'temp': 290.49, 'feels_like': 290.37, 'temp_m...
# 2   1780401600  {'temp': 290.88, 'feels_like': 290.56, 'temp_m...
# 3   1780412400  {'temp': 295.21, 'feels_like': 294.54, 'temp_m...
# 4   1780423200  {'temp': 292.32, 'feels_like': 291.52, 'temp_m...
# 5   1780434000  {'temp': 285.73, 'feels_like': 285.13, 'temp_m...
# 6   1780444800  {'temp': 284.03, 'feels_like': 283.47, 'temp_m...
# 7   1780455600  {'temp': 286.35, 'feels_like': 285.63, 'temp_m...
# 8   1780466400  {'temp': 286.91, 'feels_like': 286.22, 'temp_m...
# 9   1780477200  {'temp': 290.62, 'feels_like': 289.96, 'temp_m...
# 10  1780488000  {'temp': 294.16, 'feels_like': 293.41, 'temp_m...
# 11  1780498800  {'temp': 295.27, 'feels_like': 294.69, 'temp_m...
# 12  1780509600  {'temp': 293.71, 'feels_like': 293.18, 'temp_m...
# ...
