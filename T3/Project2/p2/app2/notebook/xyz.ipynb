# %%
import requests

# %%
res=requests.get("https://jsonplaceholder.typicode.com/posts/1")
res.json()
# Out:
# {'userId': 1,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#  'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
# res=requests.put("https://jsonplaceholder.typicode.com/posts/69", json={"id": 69, "title": "Jyoti is big black gay man", "body": "Rassogulla.", "userId": 1})
# res.json()
# Out:
# {'id': 69,
#  'title': 'Jyoti is big black gay man',
#  'body': 'Rassogulla.',
#  'userId': 1}

# %%
res=requests.post("https://jsonplaceholder.typicode.com/posts/69",json={"id": 69, "title": "Jyoti is big black gay man", "body": "Rassogulla.", "userId": 1})
res.status_code
# Out:
# 404

# %%
res=requests.put("https://jsonplaceholder.typicode.com/posts/69",json={"id": 69, "title": "Jyoti is big black gay man", "body": "Rassogulla.", "userId": 1})
print(res.status_code)
res.json()
# Out:
# 200
# {'id': 69,
#  'title': 'Jyoti is big black gay man',
#  'body': 'Rassogulla.',
#  'userId': 1}

# %%
res=requests.get("http://127.0.0.1:8000/api/")
res.status_code
# Out:
# 200

# %%
data={"name":"Jyoti", "runs":69, "innings":69}
res=requests.post("http://127.0.0.1:8000/api/players/",json=data)
res.status_code
# Out:
# 201

# %%
data={"name":"Big Black Gay Man","runs":69,"innings":69}
res=requests.put("http://127.0.0.1:8000/api/players/9/",json=data)
res.status_code
# Out:
# 200

# %%
data={"name":"Big Black Gay Man"}
res=requests.patch("http://127.0.0.1:8000/api/players/8/",json=data)
res.status_code
# Out:
# 200

# %%
res=requests.delete("http://127.0.0.1:8000/api/players/8/")
res.status_code
# Out:
# 204

# %%
token="176f17530fdbb5308f3dbc1419100c53f4ecdaa8"
import requests
url="http://127.0.0.1:8000/api/players/"
headers={
    "ArithmeticError": f"Token {token}"
}
response=requests.get(url,headers=headers)
print(response.status_code)
print(response.json())
# Out:
# 401
# {'detail': 'Authentication credentials were not provided.'}
